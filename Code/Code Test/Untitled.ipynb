# %%
# Out:
# <input>:1: DeprecationWarning: invalid escape sequence \B
# <ipython-input-5-5330179711c0>:1: DeprecationWarning: invalid escape sequence \B
#   plotting.plot_glass_brain("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz")
# C:\Users\ocandjua\AppData\Roaming\Python\Python37\site-packages\nilearn\plotting\displays.py:600: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(axes, collections.Sequence):
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\ndimage\measurements.py:272: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
# ...

# %%
from nilearn import image, plotting

smoothed_img = image.smooth_img("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz", fwhm=5)
smoothed_img.to_filename("t_map000_smoothed.nii")  
image = plotting.plot_glass_brain("t_map000_smoothed.nii")
# Out:
# <input>:2: DeprecationWarning: invalid escape sequence \B
# <ipython-input-3-9d33b035ffe7>:2: DeprecationWarning: invalid escape sequence \B
#   smoothed_img = image.smooth_img("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz", fwhm=5)

# %%
from nilearn import plotting
image = nilearn.plotting.plot_glass_brain("t_map000_smoothed.nii")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-232f35ded114> in <module>()
#       1 from nilearn import plotting
# ----> 2 image = nilearn.plotting.plot_glass_brain("t_map000_smoothed.nii")
#
# NameError: name 'nilearn' is not defined

# %%
image = plotting.plot_glass_brain("t_map000_smoothed.nii")
# Out:
# C:\Users\ocandjua\AppData\Roaming\Python\Python37\site-packages\nilearn\plotting\displays.py:600: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(axes, collections.Sequence):
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\ndimage\measurements.py:272: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)

# %%
second_volume = image.index_img("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz", 1)
# Out:
# <input>:1: DeprecationWarning: invalid escape sequence \B
# <ipython-input-12-c78944e7363c>:1: DeprecationWarning: invalid escape sequence \B
#   second_volume = image.index_img("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz", 1)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c78944e7363c> in <module>()
# ----> 1 second_volume = image.index_img("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz", 1)
#
# AttributeError: 'OrthoProjector' object has no attribute 'index_img'

# %%
premier_volume =  image.index_img("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz", 0)
# Out:
# <input>:1: DeprecationWarning: invalid escape sequence \B
# <ipython-input-13-6fa10ad813d6>:1: DeprecationWarning: invalid escape sequence \B
#   premier_volume =  image.index_img("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz", 0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-6fa10ad813d6> in <module>()
# ----> 1 premier_volume =  image.index_img("HGG\Brats17_2013_3_1\Brats17_2013_3_1_t1ce.nii.gz", 0)
#
# AttributeError: 'OrthoProjector' object has no attribute 'index_img'
